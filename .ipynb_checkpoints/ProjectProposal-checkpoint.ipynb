# %% [markdown]
# ***
# # STAT 201: Group Project Proposal
# ## [ENTER TITLE HERE]
#
# #### **Group 17**
# #### Authors: Yuening Lu, Ibrahim Saeed, Julia Sangster, Yelia Ye
# ***

# %% [markdown]
# ## **Introduction**
# ***

# %% [markdown]
# Markdown cell for introduction

# %% [markdown]
# ## **Preliminary Exploratory Data Analysis**
# ***

# %% [markdown]
# ### **Notebook Setup**

# %%
## This cell does all set-up steps for analysis

## Uncomment and run these lines if the needed packages are not installed
#install.packages("tidyverse")
#install.packages("repr")
#install.packages("tidymodels")

## The following lines load the relevant packages
suppressPackageStartupMessages(library(tidyverse))
suppressPackageStartupMessages(library(repr))

## Reduces default table-output size
options(repr.matrix.max.rows = 6)

## Sets RNG seed for the page
set.seed(9999)

## Sets a general theme for output 
theme_set(theme_bw())

# %% [markdown]
# ### **Reading Data from Repository**

# %% [markdown]
# Data was obtained from the VCD on March 9th, 2023.

# %%
suppressWarnings({
    
    ## These cells read in the crime database over 2020 and 2021
    data_2022 <- read_csv("https://raw.githubusercontent.com/juliasangster/STAT_201_Project/main/crimedata_csv_AllNeighbourhoods_2022.csv", show_col_types = FALSE)
    data_2021 <- read_csv("https://raw.githubusercontent.com/juliasangster/STAT_201_Project/main/crimedata_csv_AllNeighbourhoods_2021.csv", show_col_types = FALSE)
    data_2020 <- read_csv("https://raw.githubusercontent.com/juliasangster/STAT_201_Project/main/crimedata_csv_AllNeighbourhoods_2020.csv", show_col_types = FALSE)
    
    ## These cells combine the data into a single dataframe, and remove irrelevant columns
    all_data <- rbind(data_2022, data_2021, data_2020)
    
    ## This will show a small output, to confirm dataset was loaded
    head(all_data)
    
    })
# Out:
#   TYPE                       YEAR MONTH DAY HOUR MINUTE HUNDRED_BLOCK
# 1 Break and Enter Commercial 2022 1      3  16   19     10XX ALBERNI ST
# 2 Break and Enter Commercial 2022 6     17   5   16     10XX ALBERNI ST
# 3 Break and Enter Commercial 2022 3     15   5   14     10XX ALBERNI ST
# 4 Break and Enter Commercial 2022 3     19   6   42     10XX ALBERNI ST
# 5 Break and Enter Commercial 2022 2     23  23    0     10XX BALFOUR AVE
# 6 Break and Enter Commercial 2022 2     25  10   15     10XX BALFOUR AVE
#   NEIGHBOURHOOD X        Y
# 1 West End      491036.1 5459146
# 2 West End      491067.3 5459115
# 3 West End      491102.2 5459092
# 4 West End      491102.2 5459092
# 5 Shaughnessy   490699.8 5455444
# 6 Shaughnessy   490699.8 5455444

# %% [markdown]
# ### **Cleaning/Wrangling Data**

# %% [markdown]
# The following cleaning/wrangling steps were taken
# 1. The data was verified to have no NA values
# 2. Selected only relevant columns (`TYPE`, `YEAR`, `MONTH`, `DAY`, `NEIGHBOURHOOD`)
# 3. Converted data representing factors to `fct` data type, including `NEIGHBOURHOOD` and `TYPE`
# 4. Filtered data into lockdown/non-lockdown crime days
# 5. Create a new column indicating lockdown staus `lockdown`
# 6. Combine data sets to create final, clean data set

# %% [markdown]
# [DO SOMETHING TO CONFIRM NO NA - NOT DONE YET ]

# %%
## Step 1: No NA Values

# %%
## Step 2: Select only relevant columns 
all_data_tidy <- all_data |>
    select(TYPE, YEAR, MONTH, DAY, NEIGHBOURHOOD)

# %%
## Step 3: Convert NEIGHBOURHOOD AND YEAR 
all_data_tidy$TYPE <- as.factor(all_data_tidy$TYPE)
all_data_tidy$NEIGHBOURHOOD <- as.factor(all_data_tidy$NEIGHBOURHOOD)

# %%
## Step 4: Filter non-lockdown and lockdown days
all_data_lockdown <- all_data_tidy |>
    filter((YEAR == 2020 & MONTH == 3 & DAY >= 12) |   ## First Lockdown Starts: March 12/2020
           (YEAR == 2020 & MONTH %in% c(4,5)) |        ## 
           (YEAR == 2020 & MONTH == 6 & DAY < 25) |    ## First Lockdown Ends: June 24/2020 
           (YEAR == 2020 & MONTH == 11 & DAY >= 7) |   ## Second Lockdown Starts: Nov. 7/2020
           (YEAR == 2020 & MONTH == 12) |              ## 
           (YEAR == 2021 & MONTH %in% c(1,2,3,4,5)) |  ##
           (YEAR == 2021 & MONTH == 6 & DAY <= 15) |   ## Second Lockdown Ends: June 15/2021
           (YEAR == 2021 & MONTH == 12 & DAY >= 20) |  ## Third Lockdown Starts: Dec. 20/2021
           (YEAR == 2022 & MONTH == 1 & DAY <= 20)) |> ## Third Lockdown Ends: Jan 20/2022
    mutate(lockdown = "yes")

all_data_non_lockdown <- all_data_tidy |>
    filter(!((YEAR == 2020 & MONTH == 3 & DAY >= 12) | 
           (YEAR == 2020 & MONTH %in% c(4,5)) | 
           (YEAR == 2020 & MONTH == 6 & DAY < 25) |
           (YEAR == 2020 & MONTH == 11 & DAY >= 7) | 
           (YEAR == 2020 & MONTH == 12) | 
           (YEAR == 2021 & MONTH %in% c(1,2,3,4,5)) |
           (YEAR == 2021 & MONTH == 6 & DAY <= 15) |
           (YEAR == 2021 & MONTH == 12 & DAY >= 20) |
           (YEAR == 2022 & MONTH == 1 & DAY <= 20))) |>
    mutate(lockdown = "no")

# %%
## Step 5: Recombine lockdown and non-lockdown days, and then change lockdown varible to fct type 
all_data_tidy_wlockdown <- rbind(all_data_lockdown, all_data_non_lockdown)
all_data_tidy_wlockdown$lockdown <- as.factor(all_data_tidy_wlockdown$lockdown)
all_data_tidy_wlockdown
# Out:
#        TYPE                                                 YEAR MONTH DAY
# 1      Break and Enter Commercial                           2022 1      3
# 2      Break and Enter Commercial                           2022 1     20
# 3      Break and Enter Commercial                           2022 1     11
# ⋮      ⋮                                                    ⋮    ⋮     ⋮
# 103889 Vehicle Collision or Pedestrian Struck (with Injury) 2020 10    10
# 103890 Vehicle Collision or Pedestrian Struck (with Injury) 2020  8     6
# 103891 Vehicle Collision or Pedestrian Struck (with Injury) 2020  8     5
#        NEIGHBOURHOOD  lockdown
# 1      West End       yes
# 2      West End       yes
# 3      West End       yes
# ⋮      ⋮              ⋮
# 103889 Mount Pleasant no
# 103890 Riley Park     no
# 103891 Mount Pleasant no

# %% [markdown]
# ### Exploring the Raw Dataset

# %% [markdown]
# The days in lockdown is not equal to the days in non-lockdown for our dataset. To compare, the count of crimes will be scaled to a daily rate (crimes/day).

# %%
total_days <- all_data_tidy_wlockdown |>
    group_by(DAY, MONTH, YEAR, lockdown) |>
    summarize(.groups = "drop") |>
    group_by(lockdown) |>
    summarize(total_days = n(), .groups = "drop")

total_days
# Out:
#   lockdown total_days
# 1 no       738
# 2 yes      358

# %% [markdown]
# First, let us investigate if the daily crime rate appears higher or lower for lockdown vs. non-lockdown days, for all crimes in all neighbourhoods.

# %%
plot_data_compare_crime_lockdown <- all_data_tidy_wlockdown |>
    group_by(lockdown, DAY, MONTH, YEAR) |>
    summarize(count = n(), .groups = "drop")
    
options(repr.plot.width = 8, repr.plot.height = 8) 
plot_compare_crime_lockdown <- plot_data_compare_crime_lockdown |>
    ggplot() +
    geom_boxplot(aes(x = lockdown, y = count, fill = lockdown)) +
    labs(title = "Daily Crime Rate in Lockdown vs. Non-Lockdown Periods", 
         x = "Lockdown",
         y = "Daily Crime Rate (Crimes/Day)") +
    theme(plot.title = element_text(hjust = 0.5),
           text = element_text(size = 10),
           legend.position = "none")

plot_compare_crime_lockdown
# Out:
# plot without title

# %% [markdown]
# As it can be viewed above, over days since COVID has been a major factor in Canada, crimes appear to be lower during lockdown periods.

# %% [markdown]
# To help hypothesize what is happening, the difference in types of crimes and crime rates in different neighbourhoods was analyzed.

# %%
plot_data_compare_crime_neighbourhoods <- all_data_tidy_wlockdown |>
    group_by(lockdown, DAY, MONTH, YEAR, NEIGHBOURHOOD) |>
    summarize(count = n(), .groups = "drop")
    
options(repr.plot.width = 13, repr.plot.height = 30) 
plot_compare_crime_neighbourhoods <- plot_data_compare_crime_neighbourhoods |>
    ggplot() +
    geom_boxplot(aes(x = lockdown, y = count, fill = lockdown)) +
    facet_grid(rows = vars(NEIGHBOURHOOD), scales = "free") + 
    labs(title = "Daily Crime Rate in Lockdown vs. Non-Lockdown Periods for Different Neighbourhoods", 
         x = "Lockdown",
         y = "Daily Crime Rate (Crimes/Day)") +
    theme(plot.title = element_text(hjust = 0.5),
           text = element_text(size = 10),
           legend.position = "none")

plot_compare_crime_neighbourhoods
# Out:
# plot without title

# %% [markdown]
# It appears as though for each neighbourhood, being in lockdown or not being in lockdown does not affect daily crime rates.

# %%
plot_data_compare_crime_type <- all_data_tidy_wlockdown |>
    group_by(lockdown, DAY, MONTH, YEAR, TYPE) |>
    summarize(count = n(), .groups = "drop")
    
options(repr.plot.width = 13, repr.plot.height = 30) 
plot_compare_crime_type <- plot_data_compare_crime_type |>
    ggplot() +
    geom_boxplot(aes(x = lockdown, y = count, fill = lockdown)) +
    facet_grid(rows = vars(TYPE), scales = "free") + 
    labs(title = "Daily Crime Rate in Lockdown vs. Non-Lockdown Periods for Different Types of Crimes", 
         x = "Lockdown",
         y = "Daily Crime Rate (Crimes/Day)") +
    theme(plot.title = element_text(hjust = 0.5),
           text = element_text(size = 10),
           legend.position = "none")

plot_compare_crime_type
# Out:
# plot without title

# %% [markdown]
# It appears as well that the daily rates for different types of crimes is the same during lockdown and not, possibly with the exception of breaking and entering.
#
# Of course, these are all visually determined. To confirm the hypothesis, more complicated analysis will need to be conducted.
#
# [NOTE TO GROUP MEMBERS: WILL GET OUTPUTS IN TABLES AS WELL]

# %% [markdown]
# ### Methods: Plan

# %%
[IDEA FOR PLAN]

[FURTHER FINDINGS]

# %% [markdown]
# ### References
